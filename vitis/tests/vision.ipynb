# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import statistics as st

# %%
rec_basic = []
with open('../../../SQA-Vitis/solution1/csim/build/out_log.basic.txt','r') as file :
    for line in file:
        if ('Energy:' in line):
            rec_basic.append(float(line.split()[1]))

rec_u50 = []
with open('../../../SQA-Vitis/solution1/csim/build/out_log.u50.txt','r') as file :
    for line in file:
        if ('Energy:' in line):
            rec_u50.append(float(line.split()[1]))

print(np.min((rec_basic)))
print(np.min((rec_u50)))
# Out:
# -2850.0
# -2850.0

# %%
plt.figure(figsize=(30,10))
plt.plot(np.array(rec_basic[:]), 'o-')
plt.plot(np.array(rec_u50[:])+20, 'o-')
print(np.sum(np.array(rec_basic[:])-np.array(rec_u50[:])) == 0.0)
# Out:
# True
