# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import statistics as st

# %%
rec = []
# with open('out.txt','r') as file :
with open('../../../SQA-Vitis/solution1/csim/build/out.txt','r') as file :
    for line in file:
        if ('Energy:' in line):
            rec.append(float(line.split()[1]))

np.min(np.abs(rec))
np.argmin(np.abs(rec))
# Out:
# 4.59778

# %%
plt.figure(figsize=(30,10))
plt.plot(rec[:])
