# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import statistics as st

# %%
energy_list = []
best_list = []
with open("out.txt") as file:
    for line in file:
        if (line.find("SUM:")!=-1):
            tmp = float(line.split()[1])
            energy_list.append(tmp)
        if (line.find("BEST:")!=-1):
            tmp = float(line.split()[1])
            best_list.append(tmp)

# %%
plt.figure(figsize=(20,10))
plt.plot(energy_list[:], 'o-')
plt.plot(best_list[:], 'o-')
# Out:
# /home/edci/.local/lib/python3.8/site-packages/matplotlib/tight_bbox.py:71: RuntimeWarning: divide by zero encountered in double_scalars
#   fig.patch.set_bounds(x0 / w1, y0 / h1,
# /home/edci/.local/lib/python3.8/site-packages/matplotlib/tight_bbox.py:72: RuntimeWarning: divide by zero encountered in double_scalars
#   fig.bbox.width / w1, fig.bbox.height / h1)
# /home/edci/.local/lib/python3.8/site-packages/matplotlib/patches.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   y1 = self.convert_yunits(self._y0 + self._height)
# /home/edci/.local/lib/python3.8/site-packages/matplotlib/transforms.py:2013: RuntimeWarning: invalid value encountered in double_scalars
#   self._mtx[1, 2] += ty

# %%
time_list = []
with open("time_log.txt") as file:
    for line in file:
        time_list.append(int(line.split()[2]) / 10**6)
print(sum(time_list) / len(time_list))
# Out:
# 0.020411649999999993

# %%
plt.figure(figsize=(10,5))
plt.plot(time_list[:], 'o')
