# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import statistics as st

# %%
energy_list = []
with open("out.txt") as file:
    for line in file:
        if (line.find("SUM:")!=-1):
            tmp = float(line.split()[1])
            # tmp = math.pow(tmp, 0.125)
            energy_list.append(tmp)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_907452/2519532769.py in <module>
#       4         if (line.find("SUM:")!=-1):
#       5             tmp = float(line.split()[1])
# ----> 6             tmp = math.pow(tmp, 0.125)
#       7             energy_list.append(tmp)
#
# ValueError: math domain error

# %%
plt.figure(figsize=(30,10))
plt.plot(energy_list[:], 'o-')

# %%
time_list = []
with open("time_log.txt") as file:
    for line in file:
        time_list.append(int(line.split()[2]) / 10**6)
print(sum(time_list) / len(time_list))
# Out:
# 0.036990735999999996
